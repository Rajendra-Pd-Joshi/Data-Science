# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# Requirement already satisfied: plotly in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (6.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from plotly) (2.24.0)
# Requirement already satisfied: packaging in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from plotly) (26.2)
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.9.2 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from cufflinks) (1.17.0)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Collecting setuptools>=34.4.1 (from cufflinks)
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: ipython>=5.3.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from cufflinks) (9.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.52)
# Requirement already satisfied: psutil>=7 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipython>=5.3.0->cufflinks) (5.15.1)
# Requirement already satisfied: wcwidth in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: comm>=0.1.3 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from plotly>=4.1.1->cufflinks) (26.2)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in C:\Users\rajen\OneDrive\Desktop\Data Science\myenv\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68558 sha256=e6b0a8ceccb702b2252159fc01d5d757f0d7c5bbea9b2e9206ba51822755bc39
#   Stored in directory: c:\users\rajen\appdata\local\pip\cache\wheels\13\bc\65\1ac45445dba1052b5e837dc49f5282c8cb2f934ae9e6f62f0e
# Successfully built cufflinks
# Installing collected packages: colorlover, setuptools, cufflinks
#
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    -------------------------- ------------- 2/3 [cufflinks]
#    ---------------------------------------- 3/3 [cufflinks]
#
# Successfully installed colorlover-0.3.0 cufflinks-0.17.3 setuptools-83.0.0

# %%
import seaborn as sns
import pandas as pd
import cufflinks as cf
import plotly as pt

# %%
tips = sns.load_dataset('tips')

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips.groupby('day')['tip'].mean()
# Out:
# day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64
